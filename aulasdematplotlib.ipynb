# %% [markdown]
# <a href="https://colab.research.google.com/github/MatheusrCunha/py_class/blob/main/aulasdematplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

t = np.linspace(0, 2*np.pi, 1000)
y = np.sin(4*t)

plt.plot(t, y)
plt.title("Gráfico do cosseno")
plt.xlabel("Tempo (s)")
plt.ylabel("Amplitude")
plt.show() #gera a figura

# %%
import matplotlib.pyplot as plt
import numpy as np

t = np.linspace(0, 2*np.pi, 1000)
y = np.cos(4*t)
y1 = np.sin(4*t)

plt.figure("Cosseno")
plt.plot(t, y)
plt.title("Gráfico do cosseno")
plt.xlabel("Tempo (s)")
plt.ylabel("Amplitude")
plt.show() #gera a figura

plt.figure(2)
plt.plot(t, y1)
plt.title("Gráfico do seno")
plt.xlabel("Tempo (s)")
plt.ylabel("Amplitude")
plt.show() #gera a figura
